# %%
import numpy as np
import pandas as pd

# %%
sal = pd.read_csv('SalariesInSanFranciscoDataSet.csv')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_23644\3184198875.py:1: DtypeWarning: Columns (0: BasePay, 1: OvertimePay, 2: OtherPay, 3: Benefits, 4: Status) have mixed types. Specify dtype option on import or set low_memory=False.
#   sal = pd.read_csv('SalariesInSanFranciscoDataSet.csv')

# %%
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# ...

# %%
sal.isna().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
def clears(pay):
    if pay=='Not Provided':
        return np.nan
    else: 
        return pay

# %%
sal['BasePay'] = sal['BasePay'].apply(clears)

# %%
sal['BasePay'].isna().sum()
# Out:
# np.int64(609)

# %%
sal['BasePay']= sal['BasePay'].astype('float32')

# %%
sal['BasePay'].mean()
# Out:
# np.float32(66325.45)

# %%
sal['OvertimePay'] =sal['OvertimePay'].astype('float32')

# %%
sal['OvertimePay'].max()
# Out:
# np.float32(245131.88)

# %%
sal[sal['EmployeeName'] == 'JOSEPH DRISCOLL']['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: str

# %%
sal[sal['EmployeeName'] == 'JOSEPH DRISCOLL']['TotalPayBenefits']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %%
sal[sal['TotalPayBenefits'] == sal['TotalPayBenefits'].max()]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#        BasePay  OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.1875          0.0  400184.25      NaN  567595.43         567595.43
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN

# %%
sal[sal['TotalPayBenefits'] == sal['TotalPayBenefits'].min()] # the record it incorrect because his total pay is in minus which in impossible.
# Out:
#             Id EmployeeName                    JobTitle  BasePay  OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch      0.0          0.0
#
#        OtherPay Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148653  -618.13        0   -618.13           -618.13  2014    NaN
#
#                Agency Status
# 148653  San Francisco     PT

# %%
sal.groupby('Year')['BasePay'].mean()
# Out:
# Year
# 2011    63595.956495
# 2012    65436.406873
# 2013    69630.030258
# 2014    66564.421986
# Name: BasePay, dtype: float64

# %%
sal['JobTitle'].nunique()
# Out:
# 2159

# %%
sal['JobTitle'].value_counts().sort_values(ascending = False).head()
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: count, dtype: int64

# %%
print((sal[sal['Year'] == 2013]['JobTitle'].value_counts() == 1).sum())
# Out:
# 202

# %%
# Out:
#             Id  EmployeeName      JobTitle  BasePay  OvertimePay OtherPay  \
# 148646  148647  Not provided  Not provided      NaN          NaN      NaN
# 148650  148651  Not provided  Not provided      NaN          NaN      NaN
# 148651  148652  Not provided  Not provided      NaN          NaN      NaN
# 148652  148653  Not provided  Not provided      NaN          NaN      NaN
#
#        Benefits  TotalPay  TotalPayBenefits  Year  Notes         Agency Status
# 148646      NaN       0.0               0.0  2014    NaN  San Francisco    NaN
# 148650      NaN       0.0               0.0  2014    NaN  San Francisco    NaN
# 148651      NaN       0.0               0.0  2014    NaN  San Francisco    NaN
# 148652      NaN       0.0               0.0  2014    NaN  San Francisco    NaN

# %%
sal['JobTitle'] = sal['JobTitle'].astype('str')

# %%
count = 0
for i in sal['JobTitle'].str.title():
    if 'Chief' in i:
        count +=1
count
# Out:
# 627

# %%
sal['JobTitle'].str.contains('Chief', case = False).sum()
# Out:
# np.int64(627)

# %%
sal['title_len'] = sal['JobTitle'].apply(lambda x: len(x))

# %%
sal[['title_len','TotalPayBenefits']].corr()
# Out:
#                   title_len  TotalPayBenefits
# title_len          1.000000         -0.036878
# TotalPayBenefits  -0.036878          1.000000
